# %%
import pandas as pd
import pymongo

client = pymongo.MongoClient(
    "mongodb+srv://Kriss:Kriss206206@cluster0.rauq32w.mongodb.net/?retryWrites=true&w=majority")
db = client["NDT"]
collection = db["NDT"]
df = pd.DataFrame(list(collection.find()))

df
# Out:
#                          _id    No  \
# 0   640d4d4a214788208189d7a5   1.0
# 1   640d4d4a214788208189d7a6   2.0
# 2   640d4d4a214788208189d7a7   3.0
# 3   640d4d4a214788208189d7a8   4.0
# 4   640d4d4a214788208189d7a9   5.0
# 5   640d4d4a214788208189d7aa   6.0
# 6   640d4d4a214788208189d7ab   7.0
# 7   640d4d4a214788208189d7ac   8.0
# 8   640d4d4a214788208189d7ad   9.0
# 9   640d4d4a214788208189d7ae  10.0
# 10  640d4d4a214788208189d7af  11.0
# 11  640d4d4a214788208189d7b0  12.0
# 12  640d4d4a214788208189d7b1  13.0
# 13  640d4d4a214788208189d7b2  14.0
# 14  640d4d4a214788208189d7b3  15.0
# 15  640d4d4a214788208189d7b4  16.0
# 16  640d4d4a214788208189d7b5  17.0
# 17  640d4d4a214788208189d7b6  18.0
# 18  640d4d4a214788208189d7b7  19.0
# 19  640d4d4a214788208189d7b8   NaN
# 20  640d4d4a214788208189d7b9   NaN
# 21  640d4d4a214788208189d7ba   NaN
# 22  640d4d4a214788208189d7bb   NaN
# 23  640d4d4a214788208189d7bc   NaN
#
#                                             ID  Bvang  Thickness  RtGap  \
# 0   PL-007-CS-T25-FLAW-Olympus-HALF-SK90_Rev.1     36      25.00      3
# 1       PL-008-CS-T25-FLAW-Olympus-HALF-SK90_1     38      25.00      3
# 2       PL-010-CS-T25-FLAW-Olympus-HALF-SK90_1     38      25.00      3
# 3       PL-012-CS-T25-FLAW-Olympus-HALF-SK90_1     38      25.00      3
# 4                               3572-13-001-90     30      18.38      3
# 5                              3572-13-002-270     30      18.38      3
# 6                               3572-13-002-90     30      18.38      3
# 7                              3572-13-002-270     30      18.38      3
# 8                               3572-14-001-90     30      30.23      4
# 9                              3572-14-001-270     30      30.23      4
# 10                              3572-14-002-90     30      30.23      4
# 11                             3572-14-002-270     30      30.23      4
# 12                                27622-001-90     30      15.00      4
# 13                               27622-001-270     30      15.00      4
# 14                                27622-002-90     30      15.00      4
# 15                               27622-002-270     30      15.00      4
# 16                                27901-001-90     30      25.00      4
# 17                               27901-001-270     30      25.00      4
# 18                                27901-002-90     30      25.00      4
# 19                               27901-002-270     30      25.00      4
# 20                                27905-001-90     30      15.00      4
# 21                               27905-001-270     30      15.00      4
# 22                                27905-002-90     30      15.00      4
# 23                               27905-002-270     30      15.00      4
#
#     probeindx
# 0          30
# 1          30
# 2          30
# 3          30
# 4          24
# 5          24
# 6          24
# 7          24
# 8          32
# 9          32
# 10         36
# 11         36
# 12         14
# 13         14
# 14         14
# 15         14
# 16         20
# 17         20
# 18         26
# 19         26
# 20         13
# 21         13
# 22         13
# 23         13
